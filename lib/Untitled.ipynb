# %%
from hcpsuite import *

labels = load_list_from_file("/home/tobac/Projekte/diss/parcellations/RenSubcorticalGlasser.labels")
coords = np.loadtxt("/home/tobac/Projekte/diss/parcellations/RenSubcorticalGlasser.coords")

results_title = "Task WM, EV 2bk_places, BMI, combined"

fig_matrix, fig_matrix_clean, fig_connectome, fig_connectome_clean, web_connectome, web_connectome_clean, labels_clean, coords_clean = plot_palm_new(subtract_arrays("results_n5000_vox_tstat_cfwep_c1.nii.gz", "results_n5000_vox_tstat_cfwep_c2.nii.gz"), results_title, coords, labels, output_dir="./plot_n5000_combined", pconn_dummy="/home/tobac/Projekte/diss/hcp-suite/data/dummy_pconns/dummy_475.pconn.nii")
# Out:
# /home/tobac/.local/lib/python3.7/site-packages/nilearn/plotting/js_plotting_utils.py:76: UserWarning: you have specified symmetric_cmap=False but the map contains negative values; setting symmetric_cmap to True
#   warnings.warn('you have specified symmetric_cmap=False '
# 5 best values: [ 2.59027176  0.09323411  0.09312647 -0.09023009 -0.04421607]
# Number of values to survive the threshold of 1.3: 1
# Saving plots to ./plot_n5000_combined...
# PALM results:
# 5 best values: [ 2.59027176  0.09323411  0.09312647 -0.09023009 -0.04421607]
# Number of values to survive the threshold of 1.3: 1
#
# Top 5 connections according to p value:
# Node A (label) <-> Node B (label): p value
# 166 (R_1) <-> 64 (CRBLM_R_64): 2.5902717608667074
# 72 (CRBLM_R_72) <-> 70 (CRBLM_R_70): 0.0932341104592722
# 417 (L_PeEc) <-> 93 (CRBLM_R_93): 0.09312646527792956
# 136 (R_LO2) <-> 80 (CRBLM_L_80): -0.09023008526723085
# 162 (R_7PC) <-> 3 (CRBLM_L_03): -0.04421607108308855
